# %%
#모듈IMPORT
import pandas as pd
import statsmodels.api as sm

# %%
#데이터 불러오기
train_dataset3=pd.read_csv('test_data.csv')

# %%
train_dataset3.head()
# Out:
#    CLLT_FP_PRNO INCB_DVSN  CUST_ID  DIVIDED_SET SIU_CUST_YN  SEX  AGE  \
# 0         26646         R        1            1           N    2    4
# 1          9613         R        6            1           N    1    6
# 2          7867         P        8            1           N    1    5
# 3         24770         R       12            1           N    1    5
# 4           291         R       15            1           N    1    5
#
#   FP_CAREER  OCCP_GRP  TOTALPREM  ... RESL_CD1_COUNT  DMND_AMT_SUM  \
# 0         N         1         14  ...              2      141450.0
# 1         N        11          2  ...              3     1390000.0
# 2         Y         2         15  ...              3     2480000.0
# 3         N        17         13  ...              1       72320.0
# 4         N         1          3  ...              2     1300000.0
#
#    PAYM_AMT_SUM  NON_PAY_RATIO_SUM  CLAIM_CNT  TOTAL_VLID_HOSP_OTDA  \
# 0      141450.0                3.0          4                     5
# ...

# %%
#DIVIDED_SET 2인 행 제거
train_dataset3=train_dataset3[train_dataset3.DIVIDED_SET != 2]

# %%
train_dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7626 entries, 0 to 7625
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CLLT_FP_PRNO          7626 non-null   int64
#  1   INCB_DVSN             7626 non-null   object
#  2   CUST_ID               7626 non-null   int64
#  3   DIVIDED_SET           7626 non-null   int64
#  4   SIU_CUST_YN           7626 non-null   object
#  5   SEX                   7626 non-null   int64
#  6   AGE                   7626 non-null   int64
#  7   FP_CAREER             7626 non-null   object
#  8   OCCP_GRP              7626 non-null   int64
#  9   TOTALPREM             7626 non-null   int64
#  10  WEDD_YN               7626 non-null   object
#  11  MAX_PRM               7626 non-null   int64
#  12  RGST_YEAR             7626 non-null   int64
#  13  RGST_MONTH            7626 non-null   int64
#  14  MAX_PAYM_YEAR         7626 non-null   int64
# ...

# %%
#DIVIDED_SET, CUST_ID, CLLT_FP_PRNO제거
train_dataset3.drop(['DIVIDED_SET'], axis=1, inplace = True)
train_dataset3.drop(['CUST_ID'], axis=1, inplace = True)
train_dataset3.drop(['CLLT_FP_PRNO'], axis=1, inplace = True)

# %%
#SIU_CUST_YN Y/N ==> 1/0으로 변경
train_dataset3['SIU_CUST_YN'].replace('Y', 1, inplace = True)
train_dataset3['SIU_CUST_YN'].replace('N', 0, inplace = True)

# %%
#FP_CAREER Y/N ==> 1/0으로 변경
train_dataset3['FP_CAREER'].replace('Y', 1, inplace = True)
train_dataset3['FP_CAREER'].replace('N', 0, inplace = True)

# %%
#WEDD_YN Y/N ==> 1/0으로 변경
train_dataset3['WEDD_YN'].replace('Y', 1, inplace = True)
train_dataset3['WEDD_YN'].replace('N', 0, inplace = True)

# %%
#INCB_DVSN ==> R : 1. P : 2, C : 3
train_dataset3['INCB_DVSN'].replace('R', 1, inplace = True)
train_dataset3['INCB_DVSN'].replace('P', 2, inplace = True)
train_dataset3['INCB_DVSN'].replace('C', 3, inplace = True)

# %%
train_dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7626 entries, 0 to 7625
# Data columns (total 41 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   INCB_DVSN             7626 non-null   int64
#  1   SIU_CUST_YN           7626 non-null   int64
#  2   SEX                   7626 non-null   int64
#  3   AGE                   7626 non-null   int64
#  4   FP_CAREER             7626 non-null   int64
#  5   OCCP_GRP              7626 non-null   int64
#  6   TOTALPREM             7626 non-null   int64
#  7   WEDD_YN               7626 non-null   int64
#  8   MAX_PRM               7626 non-null   int64
#  9   RGST_YEAR             7626 non-null   int64
#  10  RGST_MONTH            7626 non-null   int64
#  11  MAX_PAYM_YEAR         7626 non-null   int64
#  12  MAX_PAYM_MONTH        7626 non-null   int64
#  13  MNTH_INCM_AMT_AVG     7626 non-null   float64
#  14  MAIN_INSR_AMT_SUM     7626 non-null   int64
# ...

# %%
train_dataset3.head()
# Out:
#    INCB_DVSN  SIU_CUST_YN  SEX  AGE  FP_CAREER  OCCP_GRP  TOTALPREM  WEDD_YN  \
# 0          1            0    2    4          0         1         14        1
# 1          1            0    1    6          0        11          2        1
# 2          2            0    1    5          1         2         15        1
# 3          1            0    1    5          0        17         13        1
# 4          1            0    1    5          0         1          3        1
#
#    MAX_PRM  RGST_YEAR  ...  RESL_CD1_COUNT  DMND_AMT_SUM  PAYM_AMT_SUM  \
# 0        3       1999  ...               2      141450.0      141450.0
# 1        0       1999  ...               3     1390000.0     1390000.0
# 2      102       1999  ...               3     2480000.0     2480000.0
# 3        7       1999  ...               1       72320.0       72320.0
# 4        5       1999  ...               2     1300000.0     1300000.0
#
#    NON_PAY_RATIO_SUM  CLAIM_CNT  TOTAL_VLID_HOSP_OTDA  HOSP_VARIES  \
# ...

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7801 entries, 0 to 8477
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SIU_CUST_YN        7801 non-null   int64
#  1   SEX                7801 non-null   int64
#  2   AGE                7801 non-null   int64
#  3   FP_CAREER          7801 non-null   int64
#  4   OCCP_GRP           7801 non-null   int64
#  5   TOTALPREM          7801 non-null   int64
#  6   MAX_PAYM_YEAR      7801 non-null   int64
#  7   MAX_PAYM_MONTH     7801 non-null   int64
#  8   MAIN_INSR_AMT_SUM  7801 non-null   int64
#  9   EXPR_SUM           7801 non-null   int64
#  10  WORK_YEARS_MIN     7801 non-null   int64
#  11  EXPR_COUNT         7801 non-null   int64
# dtypes: int64(12)
# memory usage: 792.3 KB

# %%
prediction = train_dataset3[['SIU_CUST_YN']] # y : 보험사기여부

# %%
# x1, x2, ... 나머지 변수
train_data = train_dataset3[['INCB_DVSN','SEX','AGE','FP_CAREER','OCCP_GRP','TOTALPREM','WEDD_YN','MAX_PRM','RGST_YEAR','RGST_MONTH','MAX_PAYM_YEAR','MAX_PAYM_MONTH','MNTH_INCM_AMT_AVG','MAIN_INSR_AMT_SUM','SUM_ORIG_PREM_SUM','EXPR_SUM','CNTT_TERM_AVG','WORK_YEARS_MAX','WORK_YEARS_MIN','EXPR_COUNT','MINCRDT','JPBASE_HSHD_INCM','ACCI_OCCP_GRP','CHME_LICE_NO','DMND_AMT','PAYM_AMT','NON_PAY_RATIO','HEED_HOSP_YN','CAUS_CODE_COUNT','DMND_RESN_CODE_COUNT','RESL_CD1_COUNT','DMND_AMT_SUM','PAYM_AMT_SUM','NON_PAY_RATIO_SUM','CLAIM_CNT','TOTAL_VLID_HOSP_OTDA','HOSP_VARIES','HOSP_DVSN_VARIES','CHME_LICE_COUNT','HEED_HOSP_YN_RATE']]
train_data
# Out:
#       INCB_DVSN  SEX  AGE  FP_CAREER  OCCP_GRP  TOTALPREM  WEDD_YN  MAX_PRM  \
# 0             1    2    4          0         1         14        1        3
# 1             1    1    6          0        11          2        1        0
# 2             2    1    5          1         2         15        1      102
# 3             1    1    5          0        17         13        1        7
# 4             1    1    5          0         1          3        1        5
# ...         ...  ...  ...        ...       ...        ...      ...      ...
# 7621          1    2    4          0         3          0        1        3
# 7622          2    2    5          0         2         22        1       32
# 7623          2    2    5          0         8          0        1        0
# 7624          1    2    4          0         3          0        1        0
# 7625          2    1    3          0         8          0        1        1
#
# ...

# %%
train_data = sm.add_constant(train_data, has_constant = 'add')

# %%
multi_model = sm.OLS(prediction, train_data)
fitted_multi_model = multi_model.fit()

# %%
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            SIU_CUST_YN   R-squared:                       0.263
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     69.36
# Date:                Fri, 13 Aug 2021   Prob (F-statistic):               0.00
# Time:                        14:30:20   Log-Likelihood:                -304.55
# No. Observations:                7626   AIC:                             689.1
# Df Residuals:                    7586   BIC:                             966.7
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...
