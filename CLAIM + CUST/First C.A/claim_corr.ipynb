# %%
# Data
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#warning
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d99bf9ff-8808-4efa-ae09-20855e49bf55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d99bf9ff-8808-4efa-ae09-20855e49bf55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving merged_claim_data.csv to merged_claim_data.csv

# %%
# 에디터 이용시 아래 코드로 대체
#uploaded = pd.read_csv('human_activity/features.txt', sep='\s+', header=None, names=['column_index', 'column_name'])
features = pd.read_csv('merged_claim_data.csv', sep = ',', encoding = 'utf-8', error_bad_lines=False, engine = 'python', header = None)
features = features.rename(columns=features.iloc[0])
features = features.drop(features.index[0])#첫 row는 컬럼명이 들어간 더미데이터이므로 삭제
features = features.astype('float')

# %%
#학습 및 테스트용 데이터를 데이터 프레임으로 로딩
features = features[['SIU_CUST_YN','TOTALPREM', 'MINCRDT', 'JPBASE_HSHD_INCM', 'RESL_CD1', 'CAUS_CODE', 'DMND_RESN_CODE', 'CHME_LICE_NO', 'DMND_AMT', 'PAYM_AMT', 'NON_PAY_RATIO', 'HEED_HOSP_YN', 'CLAIM_CNT', 'TOTAL_VLID_HOSP_OTDA', 'HOSP_VARIES', 'HOSP_DVSN_VARIES', 'CHME_LICE_COUNT']]

# %%
corr_data = features.corr()
corr_data = corr_data.apply(lambda x: round(x ,2))
corr_data
# Out:
#                       SIU_CUST_YN  TOTALPREM  ...  HOSP_DVSN_VARIES  CHME_LICE_COUNT
# SIU_CUST_YN                  1.00      -0.00  ...              0.35             0.43
# TOTALPREM                   -0.00       1.00  ...              0.07             0.04
# MINCRDT                      0.08      -0.17  ...              0.01             0.03
# JPBASE_HSHD_INCM            -0.02       0.23  ...              0.01             0.00
# RESL_CD1                     0.06      -0.03  ...              0.04             0.00
# CAUS_CODE                    0.07      -0.03  ...              0.04             0.00
# DMND_RESN_CODE              -0.14       0.07  ...             -0.07            -0.11
# CHME_LICE_NO                -0.02      -0.01  ...              0.00            -0.00
# DMND_AMT                     0.01      -0.00  ...             -0.02             0.01
# PAYM_AMT                     0.01      -0.00  ...             -0.02             0.01
# NON_PAY_RATIO               -0.07      -0.04  ...             -0.03            -0.03
# HEED_HOSP_YN                 0.02      -0.01  ...             -0.01             0.01
# CLAIM_CNT                    0.38       0.09  ...              0.66             0.85
# TOTAL_VLID_HOSP_OTDA         0.44       0.02  ...              0.52             0.74
# HOSP_VARIES                  0.42       0.04  ...              0.82             0.94
# HOSP_DVSN_VARIES             0.35       0.07  ...              1.00             0.77
# CHME_LICE_COUNT              0.43       0.04  ...              0.77             1.00
#
# [17 rows x 17 columns]

# %%
corr_data.to_csv('corr_data.csv')

# %%
s = corr_data.unstack()
s
# Out:
# SIU_CUST_YN      SIU_CUST_YN             1.00
#                  TOTALPREM              -0.00
#                  MINCRDT                 0.08
#                  JPBASE_HSHD_INCM       -0.02
#                  RESL_CD1                0.06
#                                          ...
# CHME_LICE_COUNT  CLAIM_CNT               0.85
#                  TOTAL_VLID_HOSP_OTDA    0.74
#                  HOSP_VARIES             0.94
#                  HOSP_DVSN_VARIES        0.77
#                  CHME_LICE_COUNT         1.00
# Length: 289, dtype: float64

# %%
# 변수간의 상관관계
df = pd.DataFrame(s[s < 1].sort_values(ascending=False), columns=['corr'])
df.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_3da60580_fc16_11eb_aae8_0242ac1c0002row0_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row1_col0{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row2_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row3_col0{
#             background-color:  #eae51a;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row4_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row5_col0{
#             background-color:  #b5de2b;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row6_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row7_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row8_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row9_col0{
#             background-color:  #a2da37;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row10_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row11_col0{
#             background-color:  #9dd93b;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row12_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row13_col0{
#             background-color:  #86d549;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row14_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row15_col0{
#             background-color:  #75d054;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row16_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row17_col0{
#             background-color:  #58c765;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row18_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row19_col0{
#             background-color:  #4ec36b;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row20_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row21_col0{
#             background-color:  #22a884;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row22_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row23_col0{
#             background-color:  #1f978b;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row24_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row25_col0{
#             background-color:  #1f958b;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row26_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row27_col0{
#             background-color:  #20938c;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row28_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row29_col0{
#             background-color:  #228b8d;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row30_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row31_col0{
#             background-color:  #25848e;
#             color:  #000000;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row32_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row33_col0{
#             background-color:  #2f6c8e;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row34_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row35_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row36_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row37_col0{
#             background-color:  #33638d;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row38_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row39_col0{
#             background-color:  #3c508b;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row40_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row41_col0{
#             background-color:  #3e4a89;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row42_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row43_col0{
#             background-color:  #3f4889;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row44_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row45_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row46_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row47_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row48_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row49_col0{
#             background-color:  #404688;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row50_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row51_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row52_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row53_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row54_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row55_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row56_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row57_col0{
#             background-color:  #414487;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row58_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row59_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row60_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row61_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row62_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row63_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row64_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row65_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row66_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row67_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row68_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row69_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row70_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row71_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row72_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row73_col0{
#             background-color:  #433e85;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row74_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row75_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row76_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row77_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row78_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row79_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row80_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row81_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row82_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row83_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row84_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row85_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row86_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row87_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row88_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row89_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row90_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row91_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row92_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row93_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row94_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row95_col0{
#             background-color:  #443b84;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row96_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row97_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row98_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row99_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row100_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row101_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row102_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row103_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row104_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row105_col0{
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }#T_3da60580_fc16_11eb_aae8_0242ac1c0002row106_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row107_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row108_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row109_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row110_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row111_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row112_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row113_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row114_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row115_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row116_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row117_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002row118_col0,#T_3da60580_fc16_11eb_aae8_0242ac1c0002r
