# %%
# Data
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#warning
import warnings
warnings.filterwarnings('ignore')

# %%
# 에디터 이용시 아래 코드로 대체
#uploaded = pd.read_csv('human_activity/features.txt', sep='\s+', header=None, names=['column_index', 'column_name'])
features = pd.read_csv('merged_claim_data.csv', sep = ',', encoding = 'utf-8', error_bad_lines=False, engine = 'python', header = None)
features = features.rename(columns=features.iloc[0])
features = features.drop(features.index[0])#첫 row는 컬럼명이 들어간 더미데이터이므로 삭제
features = features.astype('float')

# %%
features
# Out:
#            NaN  CUST_ID  SIU_CUST_YN  SEX   AGE  FP_CAREER  MAX_PRM  RESL_CD1  \
# 1          0.0   5936.0          0.0  1.0  22.0        0.0      1.0      83.0
# 2          1.0   1043.0          0.0  2.0  44.0        0.0      1.0      65.0
# 3          2.0   8545.0          0.0  2.0  56.0        0.0      2.0      73.0
# 4          5.0  20267.0          1.0  2.0  58.0        1.0      7.0      73.0
# 5          7.0   9019.0          0.0  2.0  59.0        0.0      2.0      73.0
# ...        ...      ...          ...  ...   ...        ...      ...       ...
# 14532  21934.0  14012.0          0.0  1.0  55.0        0.0      1.0      73.0
# 14533  21938.0  15203.0          0.0  2.0  55.0        0.0      4.0      75.0
# 14534  21939.0  16048.0          0.0  1.0  61.0        0.0      0.0      83.0
# 14535  21940.0   2924.0          0.0  2.0  54.0        0.0     19.0      74.0
# 14536  21941.0   6451.0          0.0  2.0  53.0        0.0      4.0      75.0
#
#        ACCI_OCCP_GRP  CHME_LICE_NO  DMND_AMT  PAYM_AMT  NON_PAY_RATIO  \
# 1               21.0           1.0       0.0       0.0            0.0
# 2                3.0           1.0       0.0       0.0            0.0
# 3                3.0           2.0       2.0       2.0            0.0
# 4                3.0           2.0      16.0      16.0            0.0
# 5               21.0           0.0       1.0       1.0            0.0
# ...              ...           ...       ...       ...            ...
# 14532            6.0           1.0       3.0       3.0            0.0
# 14533            3.0           0.0       1.0       1.0            0.0
# 14534            1.0           1.0       0.0       0.0            0.0
# 14535            2.0           0.0       0.0       0.0            0.0
# 14536            9.0           1.0       0.0       0.0            0.0
#
#        HEED_HOSP_YN  CLAIM_CNT  TOTAL_VLID_HOSP_OTDA  HOSP_VARIES  \
# 1               0.0        6.0                  12.0          1.0
# 2               0.0       10.0                 111.0          5.0
# 3               0.0        2.0                   0.0          2.0
# 4               0.0       43.0                 805.0         15.0
# 5               0.0       12.0                 168.0          4.0
# ...             ...        ...                   ...          ...
# 14532           0.0        2.0                   9.0          1.0
# 14533           0.0        2.0                   4.0          1.0
# 14534           0.0        2.0                   8.0          1.0
# 14535           0.0        1.0                  12.0          1.0
# 14536           0.0        3.0                   6.0          1.0
#
#        HOSP_DVSN_VARIES  CHME_LICE_COUNT
# 1                   1.0              2.0
# 2                   5.0              7.0
# 3                   2.0              2.0
# 4                   5.0             23.0
# 5                   2.0              5.0
# ...                 ...              ...
# 14532               1.0              1.0
# 14533               1.0              1.0
# 14534               1.0              1.0
# 14535               1.0              1.0
# 14536               1.0              1.0
#
# [14536 rows x 19 columns]

# %%
#학습 및 테스트용 데이터를 데이터 프레임으로 로딩
features = features[['SIU_CUST_YN','SEX','AGE','FP_CAREER','MAX_PRM','RESL_CD1','ACCI_OCCP_GRP','CHME_LICE_NO','DMND_AMT','PAYM_AMT','NON_PAY_RATIO','HEED_HOSP_YN','CLAIM_CNT','TOTAL_VLID_HOSP_OTDA','HOSP_VARIES','HOSP_DVSN_VARIES','CHME_LICE_COUNT']]

# %%
corr_data = features.corr()
corr_data = corr_data.apply(lambda x: round(x ,2))
corr_data
# Out:
#                       SIU_CUST_YN   SEX   AGE  FP_CAREER  MAX_PRM  RESL_CD1  \
# SIU_CUST_YN                  1.00  0.04  0.02       0.06     0.02      0.07
# SEX                          0.04  1.00  0.08       0.18     0.03     -0.11
# AGE                          0.02  0.08  1.00       0.07     0.02     -0.08
# FP_CAREER                    0.06  0.18  0.07       1.00     0.09      0.00
# MAX_PRM                      0.02  0.03  0.02       0.09     1.00     -0.01
# RESL_CD1                     0.07 -0.11 -0.08       0.00    -0.01      1.00
# ACCI_OCCP_GRP               -0.04 -0.10 -0.35      -0.04    -0.02      0.05
# CHME_LICE_NO                -0.02 -0.01 -0.04      -0.00     0.00     -0.02
# DMND_AMT                    -0.00 -0.01  0.06      -0.00    -0.01     -0.10
# PAYM_AMT                    -0.00 -0.01  0.06      -0.00    -0.01     -0.10
# NON_PAY_RATIO               -0.07  0.03 -0.12      -0.02     0.01     -0.11
# HEED_HOSP_YN                 0.02 -0.02  0.02      -0.00    -0.00     -0.02
# CLAIM_CNT                    0.37  0.03  0.09       0.09     0.06     -0.03
# TOTAL_VLID_HOSP_OTDA         0.43  0.01  0.12       0.07     0.01      0.03
# HOSP_VARIES                  0.41  0.06  0.07       0.07     0.03      0.03
# HOSP_DVSN_VARIES             0.34  0.06  0.07       0.08     0.04      0.04
# CHME_LICE_COUNT              0.42  0.05  0.09       0.07     0.03     -0.01
#
#                       ACCI_OCCP_GRP  CHME_LICE_NO  DMND_AMT  PAYM_AMT  \
# SIU_CUST_YN                   -0.04         -0.02     -0.00     -0.00
# SEX                           -0.10         -0.01     -0.01     -0.01
# AGE                           -0.35         -0.04      0.06      0.06
# FP_CAREER                     -0.04         -0.00     -0.00     -0.00
# MAX_PRM                       -0.02          0.00     -0.01     -0.01
# RESL_CD1                       0.05         -0.02     -0.10     -0.10
# ACCI_OCCP_GRP                  1.00          0.02     -0.02     -0.02
# CHME_LICE_NO                   0.02          1.00      0.00      0.00
# DMND_AMT                      -0.02          0.00      1.00      1.00
# PAYM_AMT                      -0.02          0.00      1.00      1.00
# NON_PAY_RATIO                  0.01          0.11     -0.03     -0.03
# HEED_HOSP_YN                  -0.01         -0.00      0.02      0.02
# CLAIM_CNT                     -0.03         -0.01      0.01      0.01
# TOTAL_VLID_HOSP_OTDA          -0.04         -0.02      0.02      0.02
# HOSP_VARIES                   -0.03          0.00     -0.03     -0.02
# HOSP_DVSN_VARIES              -0.03         -0.00     -0.03     -0.03
# CHME_LICE_COUNT               -0.03         -0.00     -0.01     -0.01
#
#                       NON_PAY_RATIO  HEED_HOSP_YN  CLAIM_CNT  \
# SIU_CUST_YN                   -0.07          0.02       0.37
# SEX                            0.03         -0.02       0.03
# AGE                           -0.12          0.02       0.09
# FP_CAREER                     -0.02         -0.00       0.09
# MAX_PRM                        0.01         -0.00       0.06
# RESL_CD1                      -0.11         -0.02      -0.03
# ACCI_OCCP_GRP                  0.01         -0.01      -0.03
# CHME_LICE_NO                   0.11         -0.00      -0.01
# DMND_AMT                      -0.03          0.02       0.01
# PAYM_AMT                      -0.03          0.02       0.01
# NON_PAY_RATIO                  1.00         -0.02      -0.05
# HEED_HOSP_YN                  -0.02          1.00       0.01
# CLAIM_CNT                     -0.05          0.01       1.00
# TOTAL_VLID_HOSP_OTDA          -0.09          0.01       0.82
# HOSP_VARIES                   -0.01         -0.01       0.80
# HOSP_DVSN_VARIES              -0.03         -0.01       0.67
# CHME_LICE_COUNT               -0.04          0.00       0.85
#
#                       TOTAL_VLID_HOSP_OTDA  HOSP_VARIES  HOSP_DVSN_VARIES  \
# SIU_CUST_YN                           0.43         0.41              0.34
# SEX                                   0.01         0.06              0.06
# AGE                                   0.12         0.07              0.07
# FP_CAREER                             0.07         0.07              0.08
# MAX_PRM                               0.01         0.03              0.04
# RESL_CD1                              0.03         0.03              0.04
# ACCI_OCCP_GRP                        -0.04        -0.03             -0.03
# CHME_LICE_NO                         -0.02         0.00             -0.00
# DMND_AMT                              0.02        -0.03             -0.03
# PAYM_AMT                              0.02        -0.02             -0.03
# NON_PAY_RATIO                        -0.09        -0.01             -0.03
# HEED_HOSP_YN                          0.01        -0.01             -0.01
# CLAIM_CNT                             0.82         0.80              0.67
# TOTAL_VLID_HOSP_OTDA                  1.00         0.67              0.53
# HOSP_VARIES                           0.67         1.00              0.83
# HOSP_DVSN_VARIES                      0.53         0.83              1.00
# CHME_LICE_COUNT                       0.73         0.94              0.78
#
#                       CHME_LICE_COUNT
# SIU_CUST_YN                      0.42
# SEX                              0.05
# AGE                              0.09
# FP_CAREER                        0.07
# MAX_PRM                          0.03
# RESL_CD1                        -0.01
# ACCI_OCCP_GRP                   -0.03
# CHME_LICE_NO                    -0.00
# DMND_AMT                        -0.01
# PAYM_AMT                        -0.01
# NON_PAY_RATIO                   -0.04
# HEED_HOSP_YN                     0.00
# CLAIM_CNT                        0.85
# TOTAL_VLID_HOSP_OTDA             0.73
# HOSP_VARIES                      0.94
# HOSP_DVSN_VARIES                 0.78
# CHME_LICE_COUNT                  1.00

# %%
corr_data.to_csv('corr_data.csv')

# %%
s = corr_data.unstack()
s
# Out:
# SIU_CUST_YN      SIU_CUST_YN             1.00
#                  SEX                     0.04
#                  AGE                     0.02
#                  FP_CAREER               0.06
#                  MAX_PRM                 0.02
#                                          ...
# CHME_LICE_COUNT  CLAIM_CNT               0.85
#                  TOTAL_VLID_HOSP_OTDA    0.73
#                  HOSP_VARIES             0.94
#                  HOSP_DVSN_VARIES        0.78
#                  CHME_LICE_COUNT         1.00
# Length: 289, dtype: float64

# %%
# 변수간의 상관관계
df = pd.DataFrame(s[s < 1].sort_values(ascending=False), columns=['corr'])
df.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_2b00a_row0_col0,#T_2b00a_row1_col0{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_2b00a_row2_col0,#T_2b00a_row3_col0{
#             background-color:  #d2e21b;
#             color:  #000000;
#         }#T_2b00a_row4_col0,#T_2b00a_row5_col0{
#             background-color:  #c8e020;
#             color:  #000000;
#         }#T_2b00a_row6_col0,#T_2b00a_row7_col0{
#             background-color:  #c2df23;
#             color:  #000000;
#         }#T_2b00a_row8_col0,#T_2b00a_row9_col0{
#             background-color:  #b8de29;
#             color:  #000000;
#         }#T_2b00a_row10_col0,#T_2b00a_row11_col0{
#             background-color:  #addc30;
#             color:  #000000;
#         }#T_2b00a_row12_col0,#T_2b00a_row13_col0{
#             background-color:  #93d741;
#             color:  #000000;
#         }#T_2b00a_row14_col0,#T_2b00a_row15_col0,#T_2b00a_row16_col0,#T_2b00a_row17_col0{
#             background-color:  #75d054;
#             color:  #000000;
#         }#T_2b00a_row18_col0,#T_2b00a_row19_col0{
#             background-color:  #3bbb75;
#             color:  #000000;
#         }#T_2b00a_row20_col0,#T_2b00a_row21_col0{
#             background-color:  #23a983;
#             color:  #000000;
#         }#T_2b00a_row22_col0,#T_2b00a_row23_col0{
#             background-color:  #22a785;
#             color:  #000000;
#         }#T_2b00a_row24_col0,#T_2b00a_row25_col0{
#             background-color:  #21a585;
#             color:  #000000;
#         }#T_2b00a_row26_col0,#T_2b00a_row27_col0{
#             background-color:  #1f9e89;
#             color:  #000000;
#         }#T_2b00a_row28_col0,#T_2b00a_row29_col0{
#             background-color:  #1f988b;
#             color:  #000000;
#         }#T_2b00a_row30_col0,#T_2b00a_row31_col0{
#             background-color:  #297b8e;
#             color:  #000000;
#         }#T_2b00a_row32_col0,#T_2b00a_row33_col0{
#             background-color:  #2d708e;
#             color:  #f1f1f1;
#         }#T_2b00a_row34_col0,#T_2b00a_row35_col0{
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }#T_2b00a_row36_col0,#T_2b00a_row37_col0,#T_2b00a_row38_col0,#T_2b00a_row39_col0,#T_2b00a_row40_col0,#T_2b00a_row41_col0,#T_2b00a_row42_col0,#T_2b00a_row43_col0{
#             background-color:  #306a8e;
#             color:  #f1f1f1;
#         }#T_2b00a_row44_col0,#T_2b00a_row45_col0,#T_2b00a_row46_col0,#T_2b00a_row47_col0{
#             background-color:  #31688e;
#             color:  #f1f1f1;
#         }#T_2b00a_row48_col0,#T_2b00a_row49_col0,#T_2b00a_row50_col0,#T_2b00a_row51_col0,#T_2b00a_row52_col0,#T_2b00a_row53_col0,#T_2b00a_row54_col0,#T_2b00a_row55_col0,#T_2b00a_row56_col0,#T_2b00a_row57_col0,#T_2b00a_row58_col0,#T_2b00a_row59_col0,#T_2b00a_row60_col0,#T_2b00a_row61_col0{
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }#T_2b00a_row62_col0,#T_2b00a_row63_col0,#T_2b00a_row64_col0,#T_2b00a_row65_col0,#T_2b00a_row66_col0,#T_2b00a_row67_col0,#T_2b00a_row68_col0,#T_2b00a_row69_col0,#T_2b00a_row70_col0,#T_2b00a_row71_col0,#T_2b00a_row72_col0,#T_2b00a_row73_col0{
#             background-color:  #32648e;
#             color:  #f1f1f1;
#         }#T_2b00a_row74_col0,#T_2b00a_row75_col0,#T_2b00a_row76_col0,#T_2b00a_row77_col0{
#             background-color:  #33628d;
#             color:  #f1f1f1;
#         }#T_2b00a_row78_col0,#T_2b00a_row79_col0,#T_2b00a_row80_col0,#T_2b00a_row81_col0,#T_2b00a_row82_col0,#T_2b00a_row83_col0{
#             background-color:  #34608d;
#             color:  #f1f1f1;
#         }#T_2b00a_row84_col0,#T_2b00a_row85_col0,#T_2b00a_row86_col0,#T_2b00a_row87_col0,#T_2b00a_row88_col0,#T_2b00a_row89_col0,#T_2b00a_row90_col0,#T_2b00a_row91_col0,#T_2b00a_row92_col0,#T_2b00a_row93_col0,#T_2b00a_row94_col0,#T_2b00a_row95_col0,#T_2b00a_row96_col0,#T_2b00a_row97_col0{
#             background-color:  #355e8d;
#             color:  #f1f1f1;
#         }#T_2b00a_row98_col0,#T_2b00a_row99_col0,#T_2b00a_row100_col0,#T_2b00a_row101_col0,#T_2b00a_row102_col0,#T_2b00a_row103_col0,#T_2b00a_row104_col0,#T_2b00a_row105_col0,#T_2b00a_row106_col0,#T_2b00a_row107_col0,#T_2b00a_row108_col0,#T_2b00a_row109_col0,#T_2b00a_row110_col0,#T_2b00a_row111_col0,#T_2b00a_row112_col0,#T_2b00a_row113_col0,#T_2b00a_row114_col0,#T_2b00a_row115_col0,#T_2b00a_row116_col0,#T_2b00a_row117_col0{
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }#T_2b00a_row118_col0,#T_2b00a_row119_col0,#T_2b00a_row120_col0,#T_2b00a_row121_col0,#T_2b00a_row122_col0,#T_2b00a_row123_col0,#T_2b00a_row124_col0,#T_2b00a_row125_col0,#T_2b00a_row126_col0,#T_2b00a_row127_col0,#T_2b00a_row128_col0,#T_2b00a_row129_col0,#T_2b00a_row130_col0,#T_2b00a_row131_col0,#T_2b00a_row132_col0,#T_2b00a_row133_col0{
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }#T_2b00a_row134_col0,#T_2b00a_row135_col0,#T_2b00a_row136_col0,#T_2b00a_row137_col0,#T_2b00a_row138_col0,#T_2b00a_row139_col0,#T_2b00a_row140_col0,#T_2b00a_row141_col0,#T_2b00a_row142_col0,#T_2b00a_row143_col0,#T_2b00a_row144_col0,#T_2b00a_row145_col0,#T_2b00a_row146_col0,#T_2b00a_row147_col0,#T_2b00a_row148_col0,#T_2b00a_row149_col0,#T_2b00a_row150_col0,#T_2b00a_row151_col0,#T_2b00a_row152_col0,#T_2b00a_row153_col0,#T_2b00a_row154_col0,#T_2b00a_row155_col0,#T_2b00a_row156_col0,#T_2b00a_row157_col0,#T_2b00a_row158_col0,#T_2b00a_row159_col0,#T_2b00a_row160_col0,#T_2b00a_row161_col0,#T_2b00a_row162_col0,#T_2b00a_row163_col0,#T_2b00a_row164_col0,#T_2b00a_row165_col0{
#             background-color:  #38588c;
#             color:  #f1f1f1;
#         }#T_2b00a_row166_col0,#T_2b00a_row167_col0,#T_2b00a_row168_col0,#T_2b00a_row169_col0,#T_2b00a_row170_col0,#T_2b00a_row171_col0,#T_2b00a_row172_col0,#T_2b00a_row173_col0,#T_2b00a_row174_col0,#T_2b00a_row175_col0,#T_2b00a_row176_col0,#T_2b00a_row177_col0,#T_2b00a_row178_col0,#T_2b00a_row179_col0,#T_2b00a_row180_col0,#T_2b00a_row181_col0,#T_2b00a_row182_col0,#T_2b00a_row183_col0,#T_2b00a_row184_col0,#T_2b00a_row185_col0,#T_2b00a_row186_col0,#T_2b00a_row187_col0,#T_2b00a_row188_col0,#T_2b00a_row189_col0,#T_2b00a_row190_col0,#T_2b00a_row191_col0,#T_2b00a_row192_col0,#T_2b00a_row193_col0{
#             background-color:  #39558c;
#             color:  #f1f1f1;
#         }#T_2b00a_row194_col0,#T_2b00a_row195_col0,#T_2b00a_row196_col0,#T_2b00a_row197_col0,#T_2b00a_row198_col0,#T_2b00a_row199_col0,#T_2b00a_row200_col0,#T_2b00a_row201_col0,#T_2b00a_row202_col0,#T_2b00a_row203_col0,#T_2b00a_row204_col0,#T_2b00a_row205_col0,#T_2b00a_row206_col0,#T_2b00a_row207_col0,#T_2b00a_row208_col0,#T_2b00a_row209_col0,#T_2b00a_row210_col0,#T_2b00a_row211_col0,#T_2b00a_row212_col0,#T_2b00a_row213_col0,#T_2b00a_row214_col0,#T_2b00a_row215_col0{
#             background-color:  #3a538b;
#             color:  #f1f1f1;
#         }#T_2b00a_row216_col0,#T_2b00a_row217_col0,#T_2b00a_row218_col0,#T_2b00a_row219_col0,#T_2b00a_row220_col0,#T_2b00a_row221_col0,#T_2b00a_row222_col0,#T_2b00a_row223_col0,#T_2b00a_row224_col0,#T_2b00a_row225_col0,#T_2b00a_row226_col0,#T_2b00a_row227_col0,#T_2b00a_row228_col0,#T_2b00a_row229_col0,#T_2b00a_row230_col0,#T_2b00a_row231_col0,#T_2b00a_row232_col0,#T_2b00a_row233_col0,#T_2b00a_row234_col0,#T_2b00a_row235_col0,#T_2b00a_row236_col0,#T_2b00a_row237_col0{
#             background-color:  #3b518b;
#             color:  #f1f1f1;
#         }#T_2b00a_row238_col0,#T_2b00a_row239_col0,#T_2b00a_row240_col0,#T_2b00a_row241_col0,#T_2b00a_row242_col0,#T_2b00a_row243_col0,#T_2b00a_row244_col0,#T_2b00a_row245_col0,#T_2b00a_row246_col0,#T_2b00a_row247_col0{
#             background-color:  #3c4f8a;
#             color:  #f1f1f1;
#         }#T_2b00a_row248_col0,#T_2b00a_row249_col0{
#             background-color:  #3d4d8a;
#             color:  #f1f1f1;
#         }#T_2b00a_row250_col0,#T_2b00a_row251_col0{
#             background-color:  #3f4889;
#             color:  #f1f1f1;
#         }#T_2b00a_row252_col0,#T_2b00a_row253_col0{
#             background-color:  #404688;
#             color:  #f1f1f1;
#         }#T_2b00a_row254_col0,#T_2b00a_row255_col0{
#             backgroun
